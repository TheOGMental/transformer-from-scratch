# %% [markdown]
# # Main
#
# The main area, containing the model after training.

# %%
import importlib
import T1000
importlib.reload(T1000)  # Force reload of T1000
from T1000 import *
from utility import get_gutenberg_book, get_many_books
import torch

# %% [markdown]
# ## Dataset Generation

# %%
DATA_RAW: list[str] = get_many_books([84, 15, 18, 82, 996, 2600])
print(f"{sum(len(x) for x in DATA_RAW) = }")

def create_word_to_int_mapping(texts: list[str], max_vocab_size: int = 10000) -> tuple[dict[str, int], list[list[int]]]:
    word_counts = {}
    for text in texts:
        words = text.split()
        for word in words:
            word_counts[word] = word_counts.get(word, 0) + 1
    
    vocab = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:max_vocab_size - 1]
    vocab_words = [word for word, _ in vocab]
    
    word_to_int = {"<UNK>": 0}
    for i, word in enumerate(vocab_words, 1):
        word_to_int[word] = i
    
    int_sequences = []
    for text in texts:
        words = text.split()
        int_sequence = [word_to_int.get(word, 0) for word in words]
        int_sequences.append(int_sequence)
    
    return word_to_int, int_sequences

word_to_int, int_sequences = create_word_to_int_mapping(DATA_RAW, max_vocab_size=10000)
max_token = max(max(seq) for seq in int_sequences if seq)
print(f"Vocabulary size: {len(word_to_int)}")
print(f"Max token value in int_sequences: {max_token}")
if max_token >= 10000:
    raise ValueError(f"Max token {max_token} exceeds expected vocab size 10000")
word_to_int["the"], int_sequences[0][:10]
# Out:
# Getting book 84...
# 	419422 characters read
# Getting book 15...
# 	1218778 characters read
# Getting book 18...
# 	1172824 characters read
# Getting book 82...
# 	1103796 characters read
# Getting book 996...
# 	2299352 characters read
# Getting book 2600...
# 	3208337 characters read
# sum(len(x) for x in DATA_RAW) = 9422509
# Vocabulary size: 10000
# Max token value in int_sequences: 9999
# (1, [0, 1422, 1, 0, 0, 21, 339, 0, 0, 0])

# %%
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

class TextDataset(Dataset):
    def __init__(self, sequences: list[list[int]], context_size: int):
        self.data = []
        self.targets = []
        self.context_size = context_size
        
        for sequence in sequences:
            if len(sequence) <= context_size:
                continue
            for i in range(len(sequence) - context_size):
                self.data.append(sequence[i:i + context_size])
                self.targets.append(sequence[i + 1:i + context_size + 1])
                
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return (torch.tensor(self.data[idx], dtype=torch.long),
                torch.tensor(self.targets[idx], dtype=torch.long))

def train_transformer(
    model: Transformer,
    int_sequences: list[list[int]],
    context_size: int = 10,
    batch_size: int = 32,
    num_epochs: int = 5,
    learning_rate: float = 0.001,
    device: str = "cuda" if torch.cuda.is_available() else "cpu"
):
    model = model.to(device)
    dataset = TextDataset(int_sequences, context_size)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    print(f"Training on {len(dataloader)} batches per epoch")
    
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        num_batches = 0
        
        for batch_idx, (inputs, targets) in enumerate(dataloader):
            if inputs.max().item() >= model.embedding.num_embeddings:
                raise ValueError(f"Input contains value {inputs.max().item()} >= vocab size {model.embedding.num_embeddings}")
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            outputs = outputs.view(-1, model.embedding.num_embeddings)
            targets = targets.view(-1)
            
            loss = criterion(outputs, targets)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            
            total_loss += loss.item()
            num_batches += 1
            
            if batch_idx % 100 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx}/{len(dataloader)}, Loss: {loss.item():.4f}")
        
        avg_loss = total_loss / num_batches
        print(f"Epoch {epoch+1}/{num_epochs} completed. Average Loss: {avg_loss:.4f}")

# Initialize and train
config = GPTConfig()
model = Transformer(config)
print(f"Model vocab size: {model.embedding.num_embeddings}")
train_transformer(model, int_sequences)
# Out:
# Model vocab size: 10000
# Batch 0: max input value = 8913
# Batch 1: max input value = 7505
# Batch 2: max input value = 9910
# Batch 3: max input value = 9782
# Batch 4: max input value = 9570
# Batch 5: max input value = 9576
# Batch 6: max input value = 9989
# Batch 7: max input value = 9798
# Batch 8: max input value = 9845
# Batch 9: max input value = 9824
# Batch 10: max input value = 9460
# Batch 11: max input value = 9937
# Batch 12: max input value = 9376
# Batch 13: max input value = 9797
# Batch 14: max input value = 9802
# Batch 15: max input value = 9797
# Batch 16: max input value = 9840
# Batch 17: max input value = 9634
# Batch 18: max input value = 9895
# Batch 19: max input value = 9831
# Batch 20: max input value = 9974
# Batch 21: max input value = 9955
# Batch 22: max input value = 9540
# Batch 23: max input value = 9603
# Batch 24: max input value = 9747
# Batch 25: max input value = 9987
# Batch 26: max input value = 9679
# Batch 27: max input value = 9374
# Batch 28: max input value = 9290
# Batch 29: max input value = 9676
# Batch 30: max input value = 8918
# Batch 31: max input value = 9269
# Batch 32: max input value = 9982
# Batch 33: max input value = 9494
# Batch 34: max input value = 9881
# Batch 35: max input value = 9236
# Batch 36: max input value = 9765
# Batch 37: max input value = 9754
# Batch 38: max input value = 9225
# Batch 39: max input value = 9638
# Batch 40: max input value = 9260
# Batch 41: max input value = 9805
# Batch 42: max input value = 8689
# Batch 43: max input value = 9887
# Batch 44: max input value = 9546
# Batch 45: max input value = 9593
# Batch 46: max input value = 9159
# Batch 47: max input value = 9800
# Batch 48: max input value = 9841
# Batch 49: max input value = 8795
# Batch 50: max input value = 9416
# Batch 51: max input value = 8782
# Batch 52: max input value = 9200
# Batch 53: max input value = 9627
# Batch 54: max input value = 9786
# Batch 55: max input value = 9959
# Batch 56: max input value = 9633
# Batch 57: max input value = 9863
# Batch 58: max input value = 9673
# Batch 59: max input value = 9170
# Batch 60: max input value = 9879
# Batch 61: max input value = 8271
# Batch 62: max input value = 9789
# Batch 63: max input value = 9694
# Batch 64: max input value = 9738
# Batch 65: max input value = 9364
# Batch 66: max input value = 9758
# Batch 67: max input value = 9963
# Batch 68: max input value = 9707
# Batch 69: max input value = 9758
# Batch 70: max input value = 9813
# Batch 71: max input value = 9401
# Batch 72: max input value = 8247
# Batch 73: max input value = 9753
# Batch 74: max input value = 9650
# Batch 75: max input value = 9957
# Batch 76: max input value = 9466
# Batch 77: max input value = 9896
# Batch 78: max input value = 9172
# Batch 79: max input value = 8923
# Batch 80: max input value = 9629
# Batch 81: max input value = 9552
# Batch 82: max input value = 9734
# Batch 83: max input value = 9840
# Batch 84: max input value = 9186
# Batch 85: max input value = 9819
# Batch 86: max input value = 9806
# Batch 87: max input value = 9408
# Batch 88: max input value = 9387
# Batch 89: max input value = 9685
# Batch 90: max input value = 9869
# Batch 91: max input value = 9722
# Batch 92: max input value = 9883
# Batch 93: max input value = 9774
# Batch 94: max input value = 9921
# Batch 95: max input value = 9447
# Batch 96: max input value = 9927
# Batch 97: max input value = 8466
# Batch 98: max input value = 9596
# Batch 99: max input value = 9498
# Batch 100: max input value = 9979
# Epoch 1/5, Batch 100/52072, Loss: 6.5963
# Batch 101: max input value = 9554
# Batch 102: max input value = 9604
# Batch 103: max input value = 9992
# Batch 104: max input value = 9428
# Batch 105: max input value = 9935
# Batch 106: max input value = 9533
# Batch 107: max input value = 9696
# Batch 108: max input value = 9169
# Batch 109: max input value = 9250
# Batch 110: max input value = 9025
# Batch 111: max input value = 9456
# Batch 112: max input value = 9807
# Batch 113: max input value = 9881
# Batch 114: max input value = 9996
# Batch 115: max input value = 9815
# Batch 116: max input value = 9405
# Batch 117: max input value = 9018
# Batch 118: max input value = 9841
# Batch 119: max input value = 9483
# Batch 120: max input value = 9859
# Batch 121: max input value = 9412
# Batch 122: max input value = 9773
# Batch 123: max input value = 9728
# Batch 124: max input value = 9943
# Batch 125: max input value = 9240
# Batch 126: max input value = 9657
# Batch 127: max input value = 8971
# Batch 128: max input value = 9334
# Batch 129: max input value = 9481
# Batch 130: max input value = 9515
# Batch 131: max input value = 9688
# Batch 132: max input value = 9997
# Batch 133: max input value = 8610
# Batch 134: max input value = 9462
# Batch 135: max input value = 9784
# Batch 136: max input value = 9569
# Batch 137: max input value = 9916
# Batch 138: max input value = 9641
# Batch 139: max input value = 9966
# Batch 140: max input value = 9877
# Batch 141: max input value = 9725
# Batch 142: max input value = 9905
# Batch 143: max input value = 9088
# Batch 144: max input value = 9651
# Batch 145: max input value = 9399
# Batch 146: max input value = 8811
# Batch 147: max input value = 9900
# Batch 148: max input value = 9909
# Batch 149: max input value = 9970
# Batch 150: max input value = 9613
# Batch 151: max input value = 9777
# Batch 152: max input value = 9907
# Batch 153: max input value = 9848
# Batch 154: max input value = 9601
# Batch 155: max input value = 9043
# Batch 156: max input value = 9969
# Batch 157: max input value = 9903
# Batch 158: max input value = 9591
# Batch 159: max input value = 9888
# Batch 160: max input value = 9774
# Batch 161: max input value = 9786
# Batch 162: max input value = 9794
# Batch 163: max input value = 9064
# Batch 164: max input value = 8330
# Batch 165: max input value = 9279
# Batch 166: max input value = 9861
# Batch 167: max input value = 9829
# Batch 168: max input value = 9863
# Batch 169: max input value = 9853
# Batch 170: max input value = 9782
# Batch 171: max input value = 8441
# Batch 172: max input value = 8619
# Batch 173: max input value = 9634
# Batch 174: max input value = 9375
# Batch 175: max input value = 9704
# Batch 176: max input value = 9818
# Batch 177: max input value = 9964
# Batch 178: max input value = 9972
# Batch 179: max input value = 9953
# Batch 180: max input value = 9572
# Batch 181: max input value = 9957
# Batch 182: max input value = 8873
# Batch 183: max input value = 9608
# Batch 184: max input value = 9898
# Batch 185: max input value = 8218
# Batch 186: max input value = 9592
# Batch 187: max input value = 9660
# Batch 188: max input value = 9960
# Batch 189: max input value = 9962
# Batch 190: max input value = 9763
# Batch 191: max input value = 9908
# Batch 192: max input value = 9899
# Batch 193: max input value = 9186
# Batch 194: max input value = 9281
# Batch 195: max input value = 9730
# Batch 196: max input value = 9712
# Batch 197: max input value = 9666
# Batch 198: max input value = 9751
# Batch 199: max input value = 9841
# Batch 200: max input value = 9921
# Epoch 1/5, Batch 200/52072, Loss: 6.3678
# Batch 201: max input value = 9872
# Batch 202: max input value = 8781
# Batch 203: max input value = 9800
# Batch 204: max input value = 9208
# Batch 205: max input value = 9883
# Batch 206: max input value = 9791
# Batch 207: max input value = 9938
# Batch 208: max input value = 9797
# Batch 209: max input value = 9928
# Batch 210: max input value = 9729
# Batch 211: max input value = 9475
# Batch 212: max input value = 9790
# Batch 213: max input value = 9517
# Batch 214: max input value = 9711
# Batch 215: max input value = 9835
# Batch 216: max input value = 9407
# Batch 217: max input value = 8973
# Batch 218: max input value = 9564
# Batch 219: max input value = 9602
# Batch 220: max input value = 9493
# Batch 221: max input value = 9592
# Batch 222: max input value = 9447
# Batch 223: max input value = 8419
# Batch 224: max input value = 9723
# Batch 225: max input value = 9998
# Batch 226: max input value = 9969
# Batch 227: max input value = 9967
# Batch 228: max input value = 9256
# Batch 229: max input value = 8879
# Batch 230: max input value = 9484
# Batch 231: max input value = 9214
# Batch 232: max input value = 9758
# Batch 233: max input value = 9945
# Batch 234: max input value = 9971
# Batch 235: max input value = 9404
# Batch 236: max input value = 9913
# Batch 237: max input value = 9649
# Batch 238: max input value = 8563
# Batch 239: max input value = 9781
# Batch 240: max input value = 9515
# Batch 241: max input value = 9087
# Batch 242: max input value = 9982
# Batch 243: max input value = 9963
# Batch 244: max input value = 9746
# Batch 245: max input value = 9962
# Batch 246: max input value = 9841
# Batch 247: max input value = 9727
# Batch 248: max input value = 9975
# Batch 249: max input value = 9591
# Batch 250: max input value = 9719
# Batch 251: max input value = 9494
# Batch 252: max input value = 8917
# Batch 253: max input value = 9916
# Batch 254: max input value = 9728
# Batch 255: max input value = 8857
# Batch 256: max input value = 9688
# Batch 257: max input value = 9032
# Batch 258: max input value = 9467
# Batch 259: max input value = 9516
# Batch 260: max input value = 9618
# Batch 261: max input value = 9968
# Batch 262: max input value = 9397
# Batch 263: max input value = 9949
# Batch 264: max input value = 9527
# Batch 265: max input value = 9425
# Batch 266: max input value = 9799
# Batch 267: max input value = 9922
# Batch 268: max input value = 9707
# Batch 269: max input value = 9254
# Batch 270: max input value = 9652
# Batch 271: max input value = 9199
# Batch 272: max input value = 9430
# Batch 273: max input value = 9594
# Batch 274: max input value = 9962
# Batch 275: max input value = 9571
# Batch 276: max input value = 9997
# Batch 277: max input value = 9781
# Batch 278: max input value = 9740
# Batch 279: max input value = 9970
# Batch 280: max input value = 9766
# Batch 281: max input value = 9878
# Batch 282: max input value = 9096
# Batch 283: max input value = 9910
# Batch 284: max input value = 9632
# Batch 285: max input value = 9933
# Batch 286: max input value = 9912
# Batch 287: max input value = 9820
# Batch 288: max input value = 9990
# Batch 289: max input value = 8810
# Batch 290: max input value = 9812
# Batch 291: max input value = 9552
# Batch 292: max input value = 9903
# Batch 293: max input value = 9925
# Batch 294: max input value = 9251
# Batch 295: max input value = 9579
# Batch 296: max input value = 9932
# Batch 297: max input value = 9776
# Batch 298: max input value = 9654
# Batch 299: max input value = 9656
# Batch 300: max input value = 9903
# Epoch 1/5, Batch 300/52072, Loss: 6.3357
# Batch 301: max input value = 9960
# Batch 302: max input value = 9403
# Batch 303: max input value = 9365
# Batch 304: max input value = 9942
# Batch 305: max input value = 9391
# Batch 306: max input value = 9341
# Batch 307: max input value = 9186
# Batch 308: max input value = 9995
# Batch 309: max input value = 9904
# Batch 310: max input value = 9887
# Batch 311: max input value = 9964
# Batch 312: max input value = 8938
# Batch 313: max input value = 9563
# Batch 314: max input value = 9726
# Batch 315: max input value = 9996
# Batch 316: max input value = 9926
# Batch 317: max input value = 9923
# Batch 318: max input value = 9849
# Batch 319: max input value = 9985
# Batch 320: max input value = 9445
# Batch 321: max input value = 9944
# Batch 322: max input value = 9887
# Batch 323: max input value = 9950
# Batch 324: max input value = 9984
# Batch 325: max input value = 9442
# Batch 326: max input value = 9113
# Batch 327: max input value = 9489
# Batch 328: max input value = 9494
# Batch 329: max input value = 9453
# Batch 330: max input value = 9872
# Batch 331: max input value = 9504
# Batch 332: max input value = 9570
# Batch 333: max input value = 9677
# Batch 334: max input value = 9825
# Batch 335: max input value = 9681
# Batch 336: max input value = 9756
# Batch 337: max input value = 9709
# Batch 338: max input value = 9584
# Batch 339: max input value = 9495
# Batch 340: max input value = 9801
# Batch 341: max input value = 9860
# Batch 342: max input value = 9501
# Batch 343: max input value = 9339
# Batch 344: max input value = 9504
# Batch 345: max input value = 9683
# Batch 346: max input value = 9755
# Batch 347: max input value = 9962
# Batch 348: max input value = 9597
# Batch 349: max input value = 9897
# Batch 350: max input value = 9140
# Batch 351: max input value = 9372
# Batch 352: max input value = 9982
# Batch 353: max input value = 9321
# Batch 354: max input value = 8486
# Batch 355: max input value = 9935
# Batch 356: max input value = 9786
# Batch 357: max input value = 9692
# Batch 358: max input value = 9722
# Batch 359: max input value = 9952
# Batch 360: max input value = 9375
# Batch 361: max input value = 9973
# Batch 362: max input value = 8234
# Batch 363: max input value = 9320
# Batch 364: max input value = 9894
# Batch 365: max input value = 9972
# Batch 366: max input value = 8959
# Batch 367: max input value = 9193
# Batch 368: max input value = 9894
# Batch 369: max input value = 9947
# Batch 370: max input value = 9599
# Batch 371: max input value = 9870
# Batch 372: max input value = 9774
# Batch 373: max input value = 8480
# Batch 374: max input value = 8649
# Batch 375: max input value = 9638
# Batch 376: max input value = 8617
# Batch 377: max input value = 8145
# Batch 378: max input value = 9763
# Batch 379: max input value = 9934
# Batch 380: max input value = 9434
# Batch 381: max input value = 9564
# Batch 382: max input value = 9672
# Batch 383: max input value = 9520
# Batch 384: max input value = 9689
# Batch 385: max input value = 9985
# Batch 386: max input value = 7995
# Batch 387: max input value = 9955
# Batch 388: max input value = 9405
# Batch 389: max input value = 9881
# Batch 390: max input value = 9690
# Batch 391: max input value = 9888
# Batch 392: max input value = 9686
# Batch 393: max input value = 9359
# Batch 394: max input value = 9682
# Batch 395: max input value = 9561
# Batch 396: max input value = 7240
# Batch 397: max input value = 9410
# Batch 398: max input value = 9782
# Batch 399: max input value = 9196
# Batch 400: max input value = 8789
# Epoch 1/5, Batch 400/52072, Loss: 6.2375
# Batch 401: max input value = 9982
# Batch 402: max input value = 9995
# Batch 403: max input value = 9774
# Batch 404: max input value = 9962
# Batch 405: max input value = 9745
# Batch 406: max input value = 9912
# Batch 407: max input value = 9672
# Batch 408: max input value = 9712
# Batch 409: max input value = 9870
# Batch 410: max input value = 9831
# Batch 411: max input value = 9736
# Batch 412: max input value = 9992
# Batch 413: max input value = 9859
# Batch 414: max input value = 9778
# Batch 415: max input value = 9674
# Batch 416: max input value = 9669
# Batch 417: max input value = 9417
# Batch 418: max input value = 9897
# Batch 419: max input value = 8930
# Batch 420: max input value = 9285
# Batch 421: max input value = 9056
# Batch 422: max input value = 8999
# Batch 423: max input value = 9591
# Batch 424: max input value = 9872
# Batch 425: max input value = 9635
# Batch 426: max input value = 8918
# Batch 427: max input value = 9237
# Batch 428: max input value = 9933
# Batch 429: max input value = 9464
# Batch 430: max input value = 8952
# Batch 431: max input value = 9346
# Batch 432: max input value = 9666
# Batch 433: max input value = 9161
# Batch 434: max input value = 8974
# Batch 435: max input value = 9764
# Batch 436: max input value = 9562
# Batch 437: max input value = 9897
# Batch 438: max input value = 9916
# Batch 439: max input value = 8024
# Batch 440: max input value = 9993
# Batch 441: max input value = 9073
# Batch 442: max input value = 9800
# Batch 443: max input value = 9874
# Batch 444: max input value = 9625
# Batch 445: max input value = 9861
# Batch 446: max input value = 9702
# Batch 447: max input value = 9695
# Batch 448: max input value = 9376
# Batch 449: max input value = 9902
# Batch 450: max input value = 9803
# Batch 451: max input value = 9994
# Batch 452: max input value = 9795
# Batch 453: max input value = 9772
# Batch 454: max input value = 9503
# Batch 455: max input value = 9464
# Batch 456: max input value = 9307
# Batch 457: max input value = 8793
# Batch 458: max input value = 9424
# Batch 459: max input value = 9482
# Batch 460: max input value = 9996
# Batch 461: max input value = 9775
# Batch 462: max input value = 9512
# Batch 463: max input value = 9693
# Batch 464: max input value = 9770
# Batch 465: max input value = 9949
# Batch 466: max input value = 9939
# Batch 467: max input value = 8780
# Batch 468: max input value = 9816
# Batch 469: max input value = 9788
# Batch 470: max input value = 9656
# Batch 471: max input value = 9779
# Batch 472: max input value = 9739
# Batch 473: max input value = 9478
# Batch 474: max input value = 9285
# Batch 475: max input value = 9923
# Batch 476: max input value = 9547
# Batch 477: max input value = 9942
# Batch 478: max input value = 9866
# Batch 479: max input value = 8969
# Batch 480: max input value = 9940
# Batch 481: max input value = 9086
# Batch 482: max input value = 9617
# Batch 483: max input value = 9218
# Batch 484: max input value = 8851
# Batch 485: max input value = 9984
# Batch 486: max input value = 9465
# Batch 487: max input value = 9897
# Batch 488: max input value = 9620
# Batch 489: max input value = 9146
# Batch 490: max input value = 9969
# Batch 491: max input value = 9494
# Batch 492: max input value = 9311
# Batch 493: max input value = 9658
# Batch 494: max input value = 9875
# Batch 495: max input value = 9100
# Batch 496: max input value = 9462
# Batch 497: max input value = 9378
# Batch 498: max input value = 9170
# Batch 499: max input value = 9662
# Batch 500: max input value = 9186
# Epoch 1/5, Batch 500/52072, Loss: 5.8838
# Batch 501: max input value = 9935
# Batch 502: max input value = 9588
# Batch 503: max input value = 9513
# Batch 504: max input value = 9994
# Batch 505: max input value = 9705
# Batch 506: max input value = 9890
# Batch 507: max input value = 9958
# Batch 508: max input value = 9429
# Batch 509: max input value = 9973
# Batch 510: max input value = 9880
# Batch 511: max input value = 9988
# Batch 512: max input value = 9108
# Batch 513: max input value = 9297
# Batch 514: max input value = 9520
# Batch 515: max input value = 9517
# Batch 516: max input value = 9488
# Batch 517: max input value = 9958
# Batch 518: max input value = 9768
# Batch 519: max input value = 9590
# Batch 520: max input value = 9094
# Batch 521: max input value = 9531
# Batch 522: max input value = 9775
# Batch 523: max input value = 9431
# Batch 524: max input value = 9196
# Batch 525: max input value = 8328
# Batch 526: max input value = 9969
# Batch 527: max input value = 9392
# Batch 528: max input value = 9296
# Batch 529: max input value = 9687
# Batch 530: max input value = 9870
# Batch 531: max input value = 9932
# Batch 532: max input value = 9850
# Batch 533: max input value = 9793
# Batch 534: max input value = 9816
# Batch 535: max input value = 9710
# Batch 536: max input value = 8911
# Batch 537: max input value = 9963
# Batch 538: max input value = 9914
# Batch 539: max input value = 9882
# Batch 540: max input value = 8451
# Batch 541: max input value = 9046
# Batch 542: max input value = 8949
# Batch 543: max input value = 9687
# Batch 544: max input value = 9378
# Batch 545: max input value = 9567
# Batch 546: max input value = 9866
# Batch 547: max input value = 9960
# Batch 548: max input value = 9546
# Batch 549: max input value = 9800
# Batch 550: max input value = 9829
# Batch 551: max input value = 9833
# Batch 552: max input value = 9227
# Batch 553: max input value = 9896
# Batch 554: max input value = 9220
# Batch 555: max input value = 9992
# Batch 556: max input value = 9441
# Batch 557: max input value = 9644
# Batch 558: max input value = 9235
# Batch 559: max input value = 8931
# Batch 560: max input value = 8982
# Batch 561: max input value = 8521
# Batch 562: max input value = 9911
# Batch 563: max input value = 9771
# Batch 564: max input value = 9961
# Batch 565: max input value = 9995
# Batch 566: max input value = 9752
# Batch 567: max input value = 9838
# Batch 568: max input value = 9969
# Batch 569: max input value = 8723
# Batch 570: max input value = 8981
# Batch 571: max input value = 8857
# Batch 572: max input value = 9139
# Batch 573: max input value = 9810
# Batch 574: max input value = 9874
# Batch 575: max input value = 9309
# Batch 576: max input value = 9916
# Batch 577: max input value = 9868
# Batch 578: max input value = 9746
# Batch 579: max input value = 9368
# Batch 580: max input value = 9463
# Batch 581: max input value = 9314
# Batch 582: max input value = 9677
# Batch 583: max input value = 9938
# Batch 584: max input value = 9434
# Batch 585: max input value = 8954
# Batch 586: max input value = 9674
# Batch 587: max input value = 9971
# Batch 588: max input value = 8767
# Batch 589: max input value = 9254
# Batch 590: max input value = 9727
# Batch 591: max input value = 9520
# Batch 592: max input value = 9702
# Batch 593: max input value = 9835
# Batch 594: max input value = 9700
# Batch 595: max input value = 9212
# Batch 596: max input value = 9323
# Batch 597: max input value = 9943
# Batch 598: max input value = 9583
# Batch 599: max input value = 9554
# Batch 600: max input value = 9708
# Epoch 1/5, Batch 600/52072, Loss: 6.1290
# Batch 601: max input value = 9992
# Batch 602: max input value = 9201
# Batch 603: max input value = 9934
# Batch 604: max input value = 9208
# Batch 605: max input value = 9452
# Batch 606: max input value = 9920
# Batch 607: max input value = 9594
# Batch 608: max input value = 9912
# Batch 609: max input value = 9945
# Batch 610: max input value = 9856
# Batch 611: max input value = 9834
# Batch 612: max input value = 9812
# Batch 613: max input value = 9750
# Batch 614: max input value = 9778
# Batch 615: max input value = 9718
# Batch 616: max input value = 9771
# Batch 617: max input value = 9665
# Batch 618: max input value = 9939
# Batch 619: max input value = 9593
# Batch 620: max input value = 9984
# Batch 621: max input value = 9761
# Batch 622: max input value = 9420
# Batch 623: max input value = 8820
# Batch 624: max input value = 9865
# Batch 625: max input value = 9927
# Batch 626: max input value = 9540
# Batch 627: max input value = 9743
# Batch 628: max input value = 9793
# Batch 629: max input value = 9610
# Batch 630: max input value = 9738
# Batch 631: max input value = 9333
# Batch 632: max input value = 9921
# Batch 633: max input value = 9479
# Batch 634: max input value = 9952
# Batch 635: max input value = 9448
# Batch 636: max input value = 9656
# Batch 637: max input value = 9950
# Batch 638: max input value = 9740
# Batch 639: max input value = 9871
# Batch 640: max input value = 9691
# Batch 641: max input value = 9417
# Batch 642: max input value = 9668
# Batch 643: max input value = 9922
# Batch 644: max input value = 9900
# Batch 645: max input value = 9681
# Batch 646: max input value = 9887
# Batch 647: max input value = 7716
# Batch 648: max input value = 9613
# Batch 649: max input value = 9936
# Batch 650: max input value = 9321
# Batch 651: max input value = 9707
# Batch 652: max input value = 9995
# Batch 653: max input value = 9742
# Batch 654: max input value = 9701
# Batch 655: max input value = 9996
# Batch 656: max input value = 9956
# Batch 657: max input value = 9901
# Batch 658: max input value = 9537
# Batch 659: max input value = 9298
# Batch 660: max input value = 9908
# Batch 661: max input value = 9385
# Batch 662: max input value = 8898
# Batch 663: max input value = 9566
# Batch 664: max input value = 9182
# Batch 665: max input value = 9842
# Batch 666: max input value = 9858
# Batch 667: max input value = 9743
# Batch 668: max input value = 9980
# Batch 669: max input value = 9076
# Batch 670: max input value = 9979
# Batch 671: max input value = 8199
# Batch 672: max input value = 9241
# Batch 673: max input value = 9929
# Batch 674: max input value = 9860
# Batch 675: max input value = 9905
# Batch 676: max input value = 9926
# Batch 677: max input value = 9742
# Batch 678: max input value = 9030
# Batch 679: max input value = 9622
# Batch 680: max input value = 9836
# Batch 681: max input value = 9146
# Batch 682: max input value = 9958
# Batch 683: max input value = 9632
# Batch 684: max input value = 9901
# Batch 685: max input value = 9512
# Batch 686: max input value = 9845
# Batch 687: max input value = 9675
# Batch 688: max input value = 9673
# Batch 689: max input value = 8201
# Batch 690: max input value = 9575
# Batch 691: max input value = 9578
# Batch 692: max input value = 9974
# Batch 693: max input value = 9470
# Batch 694: max input value = 9328
# Batch 695: max input value = 9249
# Batch 696: max input value = 9995
# Batch 697: max input value = 9514
# Batch 698: max input value = 9410
# Batch 699: max input value = 9907
# Batch 700: max input value = 9415
# Epoch 1/5, Batch 700/52072, Loss: 5.9681
# Batch 701: max input value = 8539
# Batch 702: max input value = 9174
# Batch 703: max input value = 9925
# Batch 704: max input value = 8996
# Batch 705: max input value = 7990
# Batch 706: max input value = 9608
# Batch 707: max input value = 9852
# Batch 708: max input value = 9873
# Batch 709: max input value = 9873
# Batch 710: max input value = 9511
# Batch 711: max input value = 9702
# Batch 712: max input value = 9190
# Batch 713: max input value = 9611
# Batch 714: max input value = 9581
# Batch 715: max input value = 9684
# Batch 716: max input value = 9473
# Batch 717: max input value = 9538
# Batch 718: max input value = 9955
# Batch 719: max input value = 9709
# Batch 720: max input value = 9857
# Batch 721: max input value = 9613
# Batch 722: max input value = 9786
# Batch 723: max input value = 9439
# Batch 724: max input value = 9910
# Batch 725: max input value = 9833
# Batch 726: max input value = 9761
# Batch 727: max input value = 9616
# Batch 728: max input value = 9366
# Batch 729: max input value = 9672
# Batch 730: max input value = 9985
# Batch 731: max input value = 9619
# Batch 732: max input value = 9756
# Batch 733: max input value = 9531
# Batch 734: max input value = 9257
# Batch 735: max input value = 9152
# Batch 736: max input value = 9950
# Batch 737: max input value = 8938
# Batch 738: max input value = 9617
# Batch 739: max input value = 9398
# Batch 740: max input value = 8652
# Batch 741: max input value = 9964
# Batch 742: max input value = 9980
# Batch 743: max input value = 9527
# Batch 744: max input value = 9697
# Batch 745: max input value = 9842
# Batch 746: max input value = 9079
# Batch 747: max input value = 9855
# Batch 748: max input value = 9461
# Batch 749: max input value = 9501
# Batch 750: max input value = 9843
# Batch 751: max input value = 9797
# Batch 752: max input value = 9796
# Batch 753: max input value = 9769
# Batch 754: max input value = 9764
# Batch 755: max input value = 9903
# Batch 756: max input value = 9856
# Batch 757: max input value = 9826
# Batch 758: max input value = 9380
# Batch 759: max input value = 9406
# Batch 760: max input value = 9827
# Batch 761: max input value = 9792
# Batch 762: max input value = 9990
# Batch 763: max input value = 9882
# Batch 764: max input value = 9966
# Batch 765: max input value = 9920
# Batch 766: max input value = 9908
# Batch 767: max input value = 9804
# Batch 768: max input value = 9780
# Batch 769: max input value = 9339
# Batch 770: max input value = 9624
# Batch 771: max input value = 9375
# Batch 772: max input value = 9615
# Batch 773: max input value = 9379
# Batch 774: max input value = 9513
# Batch 775: max input value = 9725
# Batch 776: max input value = 9908
# Batch 777: max input value = 9533
# Batch 778: max input value = 9931
# Batch 779: max input value = 8656
# Batch 780: max input value = 9410
# Batch 781: max input value = 9999
# Batch 782: max input value = 8842
# Batch 783: max input value = 9632
# Batch 784: max input value = 9713
# Batch 785: max input value = 9793
# Batch 786: max input value = 9688
# Batch 787: max input value = 9156
# Batch 788: max input value = 9856
# Batch 789: max input value = 9820
# Batch 790: max input value = 9930
# Batch 791: max input value = 9620
# Batch 792: max input value = 9872
# Batch 793: max input value = 9705
# Batch 794: max input value = 9468
# Batch 795: max input value = 9615
# Batch 796: max input value = 9830
# Batch 797: max input value = 9576
# Batch 798: max input value = 9207
# Batch 799: max input value = 9923
# Batch 800: max input value = 9872
# Epoch 1/5, Batch 800/52072, Loss: 5.7398
# Batch 801: max input value = 9821
# Batch 802: max input value = 9724
# Batch 803: max input value = 9662
# Batch 804: max input value = 9064
# Batch 805: max input value = 9755
# Batch 806: max input value = 8648
# Batch 807: max input value = 9649
# Batch 808: max input value = 9755
# Batch 809: max input value = 9289
# Batch 810: max input value = 9501
# Batch 811: max input value = 9916
# Batch 812: max input value = 9881
# Batch 813: max input value = 9692
# Batch 814: max input value = 9369
# Batch 815: max input value = 9287
# Batch 816: max input value = 9552
# Batch 817: max input value = 9835
# Batch 818: max input value = 9862
# Batch 819: max input value = 9595
# Batch 820: max input value = 9411
# Batch 821: max input value = 9909
# Batch 822: max input value = 9899
# Batch 823: max input value = 9941
# Batch 824: max input value = 8674
# Batch 825: max input value = 9941
# Batch 826: max input value = 9856
# Batch 827: max input value = 9200
# Batch 828: max input value = 9758
# Batch 829: max input value = 9528
# Batch 830: max input value = 9728
# Batch 831: max input value = 9625
# Batch 832: max input value = 9565
# Batch 833: max input value = 9993
# Batch 834: max input value = 9666
# Batch 835: max input value = 9848
# Batch 836: max input value = 9904
# Batch 837: max input value = 9916
# Batch 838: max input value = 9402
# Batch 839: max input value = 9681
# Batch 840: max input value = 9759
# Batch 841: max input value = 8837
# Batch 842: max input value = 8199
# Batch 843: max input value = 9915
# Batch 844: max input value = 9919
# Batch 845: max input value = 9831
# Batch 846: max input value = 9680
# Batch 847: max input value = 9930
# Batch 848: max input value = 9263
# Batch 849: max input value = 9155
# Batch 850: max input value = 9928
# Batch 851: max input value = 9901
# Batch 852: max input value = 9238
# Batch 853: max input value = 9988
# Batch 854: max input value = 8847
# Batch 855: max input value = 9757
# Batch 856: max input value = 9139
# Batch 857: max input value = 9661
# Batch 858: max input value = 9496
# Batch 859: max input value = 9662
# Batch 860: max input value = 9142
# Batch 861: max input value = 9851
# Batch 862: max input value = 9699
# Batch 863: max input value = 9811
# Batch 864: max input value = 9850
# Batch 865: max input value = 9775
# Batch 866: max input value = 9837
# Batch 867: max input value = 9965
# Batch 868: max input value = 9603
# Batch 869: max input value = 9994
# Batch 870: max input value = 9485
# Batch 871: max input value = 9609
# Batch 872: max input value = 9471
# Batch 873: max input value = 9149
# Batch 874: max input value = 9944
# Batch 875: max input value = 9749
# Batch 876: max input value = 9707
# Batch 877: max input value = 9116
# Batch 878: max input value = 8970
# Batch 879: max input value = 9467
# Batch 880: max input value = 9275
# Batch 881: max input value = 9633
# Batch 882: max input value = 9741
# Batch 883: max input value = 9856
# Batch 884: max input value = 9301
# Batch 885: max input value = 8287
# Batch 886: max input value = 9719
# Batch 887: max input value = 9939
# Batch 888: max input value = 9651
# Batch 889: max input value = 9513
# Batch 890: max input value = 9599
# Batch 891: max input value = 9906
# Batch 892: max input value = 9602
# Batch 893: max input value = 9252
# Batch 894: max input value = 9891
# Batch 895: max input value = 9320
# Batch 896: max input value = 9923
# Batch 897: max input value = 9655
# Batch 898: max input value = 9604
# Batch 899: max input value = 9972
# Batch 900: max input value = 8454
# Epoch 1/5, Batch 900/52072, Loss: 5.4410
# Batch 901: max input value = 9374
# Batch 902: max input value = 9765
# Batch 903: max input value = 9147
# Batch 904: max input value = 8511
# Batch 905: max input value = 9580
# Batch 906: max input value = 8883
# Batch 907: max input value = 9471
# Batch 908: max input value = 9887
# Batch 909: max input value = 9823
# Batch 910: max input value = 9690
# Batch 911: max input value = 8211
# Batch 912: max input value = 9948
# Batch 913: max input value = 9994
# Batch 914: max input value = 9432
# Batch 915: max input value = 9861
# Batch 916: max input value = 9982
# Batch 917: max input value = 9325
# Batch 918: max input value = 9388
# Batch 919: max input value = 8472
# Batch 920: max input value = 9982
# Batch 921: max input value = 9639
# Batch 922: max input value = 9878
# Batch 923: max input value = 9829
# Batch 924: max input value = 9688
# Batch 925: max input value = 8979
# Batch 926: max input value = 9849
# Batch 927: max input value = 8132
# Batch 928: max input value = 9230
# Batch 929: max input value = 9788
# Batch 930: max input value = 9993
# Batch 931: max input value = 9965
# Batch 932: max input value = 9909
# Batch 933: max input value = 9521
# Batch 934: max input value = 9923
# Batch 935: max input value = 9326
# Batch 936: max input value = 9948
# Batch 937: max input value = 9653
# Batch 938: max input value = 9893
# Batch 939: max input value = 9090
# Batch 940: max input value = 9720
# Batch 941: max input value = 9523
# Batch 942: max input value = 9806
# Batch 943: max input value = 9879
# Batch 944: max input value = 9649
# Batch 945: max input value = 9918
# Batch 946: max input value = 9831
# Batch 947: max input value = 9907
# Batch 948: max input value = 9913
# Batch 949: max input value = 8998
# Batch 950: max input value = 9886
# Batch 951: max input value = 9925
# Batch 952: max input value = 9173
# Batch 953: max input value = 9894
# Batch 954: max input value = 9182
# Batch 955: max input value = 9979
# Batch 956: max input value = 9154
# Batch 957: max input value = 9595
# Batch 958: max input value = 9850
# Batch 959: max input value = 9780
# Batch 960: max input value = 9952
# Batch 961: max input value = 9509
# Batch 962: max input value = 9993
# Batch 963: max input value = 9027
# Batch 964: max input value = 9734
# Batch 965: max input value = 9626
# Batch 966: max input value = 9807
# Batch 967: max input value = 9777
# Batch 968: max input value = 9509
# Batch 969: max input value = 9914
# Batch 970: max input value = 9699
# Batch 971: max input value = 9668
# Batch 972: max input value = 9008
# Batch 973: max input value = 9803
# Batch 974: max input value = 9848
# Batch 975: max input value = 9612
# Batch 976: max input value = 9945
# Batch 977: max input value = 9082
# Batch 978: max input value = 9786
# Batch 979: max input value = 8917
# Batch 980: max input value = 9998
# Batch 981: max input value = 9934
# Batch 982: max input value = 9945
# Batch 983: max input value = 9976
# Batch 984: max input value = 9931
# Batch 985: max input value = 9521
# Batch 986: max input value = 9269
# Batch 987: max input value = 9694
# Batch 988: max input value = 9792
# Batch 989: max input value = 9871
# Batch 990: max input value = 9007
# Batch 991: max input value = 9934
# Batch 992: max input value = 9319
# Batch 993: max input value = 9425
# Batch 994: max input value = 9432
# Batch 995: max input value = 9802
# Batch 996: max input value = 9744
# Batch 997: max input value = 7975
# Batch 998: max input value = 9780
# Batch 999: max input value = 9682
# Batch 1000: max input value = 9738
# Epoch 1/5, Batch 1000/52072, Loss: 5.4812
# Batch 1001: max input value = 9890
# Batch 1002: max input value = 9091
# Batch 1003: max input value = 9530
# Batch 1004: max input value = 9735
# Batch 1005: max input value = 9479
# Batch 1006: max input value = 9868
# Batch 1007: max input value = 9807
# Batch 1008: max input value = 9700
# Batch 1009: max input value = 9981
# Batch 1010: max input value = 9691
# Batch 1011: max input value = 9771
# Batch 1012: max input value = 9969
# Batch 1013: max input value = 9771
# Batch 1014: max input value = 9968
# Batch 1015: max input value = 9575
# Batch 1016: max input value = 9858
# Batch 1017: max input value = 9387
# Batch 1018: max input value = 9104
# Batch 1019: max input value = 9372
# Batch 1020: max input value = 9884
# Batch 1021: max input value = 9843
# Batch 1022: max input value = 9977
# Batch 1023: max input value = 9853
# Batch 1024: max input value = 9873
# Batch 1025: max input value = 9856
# Batch 1026: max input value = 9668
# Batch 1027: max input value = 8795
# Batch 1028: max input value = 9733
# Batch 1029: max input value = 9961
# Batch 1030: max input value = 9455
# Batch 1031: max input value = 9638
# Batch 1032: max input value = 9948
# Batch 1033: max input value = 9781
# Batch 1034: max input value = 9782
# Batch 1035: max input value = 9708
# Batch 1036: max input value = 8954
# Batch 1037: max input value = 9445
# Batch 1038: max input value = 9602
# Batch 1039: max input value = 9653
# Batch 1040: max input value = 9989
# Batch 1041: max input value = 9460
# Batch 1042: max input value = 9179
# Batch 1043: max input value = 9547
# Batch 1044: max input value = 9528
# Batch 1045: max input value = 9869
# Batch 1046: max input value = 9871
# Batch 1047: max input value = 9657
# Batch 1048: max input value = 9461
# Batch 1049: max input value = 9410
# Batch 1050: max input value = 9647
# Batch 1051: max input value = 9906
# Batch 1052: max input value = 9776
# Batch 1053: max input value = 9548
# Batch 1054: max input value = 9821
# Batch 1055: max input value = 9539
# Batch 1056: max input value = 9890
# Batch 1057: max input value = 9824
# Batch 1058: max input value = 8441
# Batch 1059: max input value = 9868
# Batch 1060: max input value = 8864
# Batch 1061: max input value = 9791
# Batch 1062: max input value = 9792
# Batch 1063: max input value = 9831
# Batch 1064: max input value = 9924
# Batch 1065: max input value = 9950
# Batch 1066: max input value = 9401
# Batch 1067: max input value = 9433
# Batch 1068: max input value = 9946
# Batch 1069: max input value = 9221
# Batch 1070: max input value = 9933
# Batch 1071: max input value = 9443
# Batch 1072: max input value = 8543
# Batch 1073: max input value = 9909
# Batch 1074: max input value = 8868
# Batch 1075: max input value = 9113
# Batch 1076: max input value = 7970
# Batch 1077: max input value = 9844
# Batch 1078: max input value = 9573
# Batch 1079: max input value = 9111
# Batch 1080: max input value = 9255
# Batch 1081: max input value = 9776
# Batch 1082: max input value = 9862
# Batch 1083: max input value = 8752
# Batch 1084: max input value = 9233
# Batch 1085: max input value = 9801
# Batch 1086: max input value = 8628
# Batch 1087: max input value = 8895
# Batch 1088: max input value = 9869
# Batch 1089: max input value = 9316
# Batch 1090: max input value = 9053
# Batch 1091: max input value = 9090
# Batch 1092: max input value = 9976
# Batch 1093: max input value = 9654
# Batch 1094: max input value = 9870
# Batch 1095: max input value = 8968
# Batch 1096: max input value = 9812
# Batch 1097: max input value = 9768
# Batch 1098: max input value = 9584
# Batch 1099: max input value = 9958
# Batch 1100: max input value = 9718
# Epoch 1/5, Batch 1100/52072, Loss: 5.2924
# Batch 1101: max input value = 9918
# Batch 1102: max input value = 9303
# Batch 1103: max input value = 9066
# Batch 1104: max input value = 9957
# Batch 1105: max input value = 8739
# Batch 1106: max input value = 9942
# Batch 1107: max input value = 9561
# Batch 1108: max input value = 9818
# Batch 1109: max input value = 9741
# Batch 1110: max input value = 9951
# Batch 1111: max input value = 9559
# Batch 1112: max input value = 9737
# Batch 1113: max input value = 9822
# Batch 1114: max input value = 9584
# Batch 1115: max input value = 9626
# Batch 1116: max input value = 9479
# Batch 1117: max input value = 9676
# Batch 1118: max input value = 9959
# Batch 1119: max input value = 9700
# Batch 1120: max input value = 9659
# Batch 1121: max input value = 9534
# Batch 1122: max input value = 9517
# Batch 1123: max input value = 9324
# Batch 1124: max input value = 9519
# Batch 1125: max input value = 9840
# Batch 1126: max input value = 9832
# Batch 1127: max input value = 9418
# Batch 1128: max input value = 9550
# Batch 1129: max input value = 9726
# Batch 1130: max input value = 9621
# Batch 1131: max input value = 9886
# Batch 1132: max input value = 8244
# Batch 1133: max input value = 9914
# Batch 1134: max input value = 9542
# Batch 1135: max input value = 9737
# Batch 1136: max input value = 9300
# Batch 1137: max input value = 9782
# Batch 1138: max input value = 9850
# Batch 1139: max input value = 9608
# Batch 1140: max input value = 9944
# Batch 1141: max input value = 9462
# Batch 1142: max input value = 9876
# Batch 1143: max input value = 9767
# Batch 1144: max input value = 9479
# Batch 1145: max input value = 9433
# Batch 1146: max input value = 9492
# Batch 1147: max input value = 9730
# Batch 1148: max input value = 8886
# Batch 1149: max input value = 9908
# Batch 1150: max input value = 9898
# Batch 1151: max input value = 9006
# Batch 1152: max input value = 9244
# Batch 1153: max input value = 9952
# Batch 1154: max input value = 9795
# Batch 1155: max input value = 9697
# Batch 1156: max input value = 9351
# Batch 1157: max input value = 9957
# Batch 1158: max input value = 9347
# Batch 1159: max input value = 8945
# Batch 1160: max input value = 9880
# Batch 1161: max input value = 9774
# Batch 1162: max input value = 9726
# Batch 1163: max input value = 9035
# Batch 1164: max input value = 9768
# Batch 1165: max input value = 9620
# Batch 1166: max input value = 9554
# Batch 1167: max input value = 9101
# Batch 1168: max input value = 8994
# Batch 1169: max input value = 9860
# Batch 1170: max input value = 9778
# Batch 1171: max input value = 9886
# Batch 1172: max input value = 9363
# Batch 1173: max input value = 9881
# Batch 1174: max input value = 9804
# Batch 1175: max input value = 9650
# Batch 1176: max input value = 9974
# Batch 1177: max input value = 8484
# Batch 1178: max input value = 9725
# Batch 1179: max input value = 9883
# Batch 1180: max input value = 9556
# Batch 1181: max input value = 8725
# Batch 1182: max input value = 9784
# Batch 1183: max input value = 9855
# Batch 1184: max input value = 9613
# Batch 1185: max input value = 9377
# Batch 1186: max input value = 9754
# Batch 1187: max input value = 9802
# Batch 1188: max input value = 9239
# Batch 1189: max input value = 9859
# Batch 1190: max input value = 9157
# Batch 1191: max input value = 9524
# Batch 1192: max input value = 8888
# Batch 1193: max input value = 8757
# Batch 1194: max input value = 9999
# Batch 1195: max input value = 9759
# Batch 1196: max input value = 8964
# Batch 1197: max input value = 9988
# Batch 1198: max input value = 9819
# Batch 1199: max input value = 9896
# Batch 1200: max input value = 8827
# Epoch 1/5, Batch 1200/52072, Loss: 5.3813
# Batch 1201: max input value = 9539
# Batch 1202: max input value = 9062
# Batch 1203: max input value = 9754
# Batch 1204: max input value = 9954
# Batch 1205: max input value = 9953
# Batch 1206: max input value = 9656
# Batch 1207: max input value = 9911
# Batch 1208: max input value = 9652
# Batch 1209: max input value = 9934
# Batch 1210: max input value = 9831
# Batch 1211: max input value = 9022
# Batch 1212: max input value = 9806
# Batch 1213: max input value = 9537
# Batch 1214: max input value = 9891
# Batch 1215: max input value = 9182
# Batch 1216: max input value = 9473
# Batch 1217: max input value = 9977
# Batch 1218: max input value = 9900
# Batch 1219: max input value = 9288
# Batch 1220: max input value = 9834
# Batch 1221: max input value = 9560
# Batch 1222: max input value = 9817
# Batch 1223: max input value = 9931
# Batch 1224: max input value = 8001
# Batch 1225: max input value = 9039
# Batch 1226: max input value = 9866
# Batch 1227: max input value = 9768
# Batch 1228: max input value = 9750
# Batch 1229: max input value = 9940
# Batch 1230: max input value = 8861
# Batch 1231: max input value = 9943
# Batch 1232: max input value = 9892
# Batch 1233: max input value = 9101
# Batch 1234: max input value = 9946
# Batch 1235: max input value = 9978
# Batch 1236: max input value = 9045
# Batch 1237: max input value = 9992
# Batch 1238: max input value = 9989
# Batch 1239: max input value = 9941
# Batch 1240: max input value = 9842
# Batch 1241: max input value = 9653
# Batch 1242: max input value = 9472
# Batch 1243: max input value = 9204
# Batch 1244: max input value = 9990
# Batch 1245: max input value = 9959
# Batch 1246: max input value = 9917
# Batch 1247: max input value = 9950
# Batch 1248: max input value = 9642
# Batch 1249: max input value = 8637
# Batch 1250: max input value = 9775
# Batch 1251: max input value = 9804
# Batch 1252: max input value = 9189
# Batch 1253: max input value = 9135
# Batch 1254: max input value = 9881
# Batch 1255: max input value = 9947
# Batch 1256: max input value = 9741
# Batch 1257: max input value = 9616
# Batch 1258: max input value = 9055
# Batch 1259: max input value = 9883
# Batch 1260: max input value = 8919
# Batch 1261: max input value = 9847
# Batch 1262: max input value = 9620
# Batch 1263: max input value = 9528
# Batch 1264: max input value = 9955
# Batch 1265: max input value = 9920
# Batch 1266: max input value = 9684
# Batch 1267: max input value = 9757
# Batch 1268: max input value = 9360
# Batch 1269: max input value = 9675
# Batch 1270: max input value = 9837
# Batch 1271: max input value = 8838
# Batch 1272: max input value = 9703
# Batch 1273: max input value = 9877
# Batch 1274: max input value = 9525
# Batch 1275: max input value = 9853
# Batch 1276: max input value = 9893
# Batch 1277: max input value = 9964
# Batch 1278: max input value = 9724
# Batch 1279: max input value = 8722
# Batch 1280: max input value = 9280
# Batch 1281: max input value = 9950
# Batch 1282: max input value = 9273
# Batch 1283: max input value = 9028
# Batch 1284: max input value = 9746
# Batch 1285: max input value = 9660
# Batch 1286: max input value = 9701
# Batch 1287: max input value = 9492
# Batch 1288: max input value = 9792
# Batch 1289: max input value = 8475
# Batch 1290: max input value = 9624
# Batch 1291: max input value = 9731
# Batch 1292: max input value = 9760
# Batch 1293: max input value = 9380
# Batch 1294: max input value = 9385
# Batch 1295: max input value = 9914
# Batch 1296: max input value = 9236
# Batch 1297: max input value = 9638
# Batch 1298: max input value = 9939
# Batch 1299: max input value = 9725
# Batch 1300: max input value = 9194
# Epoch 1/5, Batch 1300/52072, Loss: 5.2894
# Batch 1301: max input value = 9874
# Batch 1302: max input value = 9988
# Batch 1303: max input value = 9860
# Batch 1304: max input value = 9001
# Batch 1305: max input value = 9097
# Batch 1306: max input value = 9905
# Batch 1307: max input value = 9992
# Batch 1308: max input value = 9139
# Batch 1309: max input value = 9922
# Batch 1310: max input value = 9736
# Batch 1311: max input value = 9762
# Batch 1312: max input value = 9986
# Batch 1313: max input value = 9258
# Batch 1314: max input value = 9957
# Batch 1315: max input value = 9716
# Batch 1316: max input value = 9020
# Batch 1317: max input value = 9986
# Batch 1318: max input value = 9678
# Batch 1319: max input value = 8613
# Batch 1320: max input value = 9945
# Batch 1321: max input value = 9267
# Batch 1322: max input value = 9444
# Batch 1323: max input value = 9709
# Batch 1324: max input value = 8970
# Batch 1325: max input value = 9904
# Batch 1326: max input value = 9816
# Batch 1327: max input value = 9905
# Batch 1328: max input value = 9194
# Batch 1329: max input value = 9946
# Batch 1330: max input value = 9936
# Batch 1331: max input value = 9898
# Batch 1332: max input value = 9989
# Batch 1333: max input value = 9846
# Batch 1334: max input value = 9294
# Batch 1335: max input value = 9758
# Batch 1336: max input value = 9830
# Batch 1337: max input value = 9417
# Batch 1338: max input value = 8687
# Batch 1339: max input value = 9713
# Batch 1340: max input value = 9632
# Batch 1341: max input value = 9679
# Batch 1342: max input value = 9709
# Batch 1343: max input value = 9899
# Batch 1344: max input value = 9801
# Batch 1345: max input value = 8994
# Batch 1346: max input value = 9918
# Batch 1347: max input value = 9644
# Batch 1348: max input value = 9973
# Batch 1349: max input value = 9776
# Batch 1350: max input value = 9982
# Batch 1351: max input value = 9305
# Batch 1352: max input value = 9068
# Batch 1353: max input value = 9505
# Batch 1354: max input value = 9734
# Batch 1355: max input value = 9925
# Batch 1356: max input value = 9928
# Batch 1357: max input value = 9949
# Batch 1358: max input value = 9890
# Batch 1359: max input value = 9772
# Batch 1360: max input value = 9929
# Batch 1361: max input value = 8814
# Batch 1362: max input value = 9112
# Batch 1363: max input value = 9993
# Batch 1364: max input value = 9850
# Batch 1365: max input value = 9997
# Batch 1366: max input value = 9365
# Batch 1367: max input value = 8746
# Batch 1368: max input value = 9026
# Batch 1369: max input value = 9900
# Batch 1370: max input value = 9476
# Batch 1371: max input value = 9016
# Batch 1372: max input value = 9934
# Batch 1373: max input value = 9137
# Batch 1374: max input value = 9394
# Batch 1375: max input value = 9734
# Batch 1376: max input value = 9503
# Batch 1377: max input value = 9875
# Batch 1378: max input value = 9795
# Batch 1379: max input value = 8513
# Batch 1380: max input value = 9617
# Batch 1381: max input value = 9724
# Batch 1382: max input value = 9746
# Batch 1383: max input value = 9833
# Batch 1384: max input value = 9767
# Batch 1385: max input value = 9915
# Batch 1386: max input value = 9986
# ...
# Batch 3462: max input value = 9935
# Batch 3463: max input value = 9667
# Batch 3464: max input value = 9964
# Batch 3465: max input value = 9620
# Batch 3466: max input value = 9313
# Batch 3467: max input value = 9203
# Batch 3468: max input value = 9815
# Batch 3469: max input value = 9920
# Batch 3470: max input value = 9946
# Batch 3471: max input value = 9554
# Batch 3472: max input value = 9781
# Batch 3473: max input value = 9201
# Batch 3474: max input value = 9632
# Batch 3475: max input value = 9838
# Batch 3476: max input value = 9948
# Batch 3477: max input value = 9382
# Batch 3478: max input value = 9704
# Batch 3479: max input value = 9990
# Batch 3480: max input value = 9923
# Batch 3481: max input value = 9971
# Batch 3482: max input value = 9345
# Batch 3483: max input value = 9818
# Batch 3484: max input value = 9819
# Batch 3485: max input value = 9525
# Batch 3486: max input value = 9771
# Batch 3487: max input value = 9789
# Batch 3488: max input value = 9684
# Batch 3489: max input value = 9615
# Batch 3490: max input value = 9694
# Batch 3491: max input value = 8761
# Batch 3492: max input value = 9844
# Batch 3493: max input value = 8744
# Batch 3494: max input value = 9303
# Batch 3495: max input value = 9947
# Batch 3496: max input value = 9568
# Batch 3497: max input value = 9067
# Batch 3498: max input value = 9560
# Batch 3499: max input value = 9707
# Batch 3500: max input value = 9178
# Epoch 1/5, Batch 3500/52072, Loss: 4.9012
# Batch 3501: max input value = 9595
# Batch 3502: max input value = 9886
# Batch 3503: max input value = 9999
# Batch 3504: max input value = 9264
# Batch 3505: max input value = 9953
# Batch 3506: max input value = 9394
# Batch 3507: max input value = 9907
# Batch 3508: max input value = 9800
# Batch 3509: max input value = 9310
# Batch 3510: max input value = 9887
# Batch 3511: max input value = 9919
# Batch 3512: max input value = 9328
# Batch 3513: max input value = 9451
# Batch 3514: max input value = 8281
# Batch 3515: max input value = 9863
# Batch 3516: max input value = 9389
# Batch 3517: max input value = 8782
# Batch 3518: max input value = 9804
# Batch 3519: max input value = 9896
# Batch 3520: max input value = 9820
# Batch 3521: max input value = 9896
# Batch 3522: max input value = 9996
# Batch 3523: max input value = 8996
# Batch 3524: max input value = 9345
# Batch 3525: max input value = 9867
# Batch 3526: max input value = 9985
# Batch 3527: max input value = 9681
# Batch 3528: max input value = 9466
# Batch 3529: max input value = 8917
# Batch 3530: max input value = 9010
# Batch 3531: max input value = 9786
# Batch 3532: max input value = 9774
# Batch 3533: max input value = 8903
# Batch 3534: max input value = 9699
# Batch 3535: max input value = 9961
# Batch 3536: max input value = 9392
# Batch 3537: max input value = 8994
# Batch 3538: max input value = 9802
# Batch 3539: max input value = 9830
# Batch 3540: max input value = 9342
# Batch 3541: max input value = 8634
# Batch 3542: max input value = 9520
# Batch 3543: max input value = 9849
# Batch 3544: max input value = 9416
# Batch 3545: max input value = 9423
# Batch 3546: max input value = 9897
# Batch 3547: max input value = 9459
# Batch 3548: max input value = 9497
# Batch 3549: max input value = 9691
# Batch 3550: max input value = 9404
# Batch 3551: max input value = 9608
# Batch 3552: max input value = 9749
# Batch 3553: max input value = 8934
# Batch 3554: max input value = 9959
# Batch 3555: max input value = 9789
# Batch 3556: max input value = 9947
# Batch 3557: max input value = 8990
# Batch 3558: max input value = 9873
# Batch 3559: max input value = 9653
# Batch 3560: max input value = 9910
# Batch 3561: max input value = 9574
# Batch 3562: max input value = 9745
# Batch 3563: max input value = 9251
# Batch 3564: max input value = 9797
# Batch 3565: max input value = 9321
# Batch 3566: max input value = 8900
# Batch 3567: max input value = 9262
# Batch 3568: max input value = 9179
# Batch 3569: max input value = 8668
# Batch 3570: max input value = 8588
# Batch 3571: max input value = 9620
# Batch 3572: max input value = 9068
# Batch 3573: max input value = 9336
# Batch 3574: max input value = 9354
# Batch 3575: max input value = 9808
# Batch 3576: max input value = 9970
# Batch 3577: max input value = 9314
# Batch 3578: max input value = 9558
# Batch 3579: max input value = 8763
# Batch 3580: max input value = 9815
# Batch 3581: max input value = 9971
# Batch 3582: max input value = 8972
# Batch 3583: max input value = 9538
# Batch 3584: max input value = 9317
# Batch 3585: max input value = 9821
# Batch 3586: max input value = 9589
# Batch 3587: max input value = 9893
# Batch 3588: max input value = 9989
# Batch 3589: max input value = 9020
# Batch 3590: max input value = 8567
# Batch 3591: max input value = 9746
# Batch 3592: max input value = 9989
# Batch 3593: max input value = 9518
# Batch 3594: max input value = 9800
# Batch 3595: max input value = 9695
# Batch 3596: max input value = 9520
# Batch 3597: max input value = 7871
# Batch 3598: max input value = 9261
# Batch 3599: max input value = 8947
# Batch 3600: max input value = 9572
# Epoch 1/5, Batch 3600/52072, Loss: 4.7721
# Batch 3601: max input value = 9962
# Batch 3602: max input value = 8972
# Batch 3603: max input value = 8658
# Batch 3604: max input value = 9951
# Batch 3605: max input value = 9057
# Batch 3606: max input value = 9273
# Batch 3607: max input value = 9614
# Batch 3608: max input value = 9943
# Batch 3609: max input value = 9970
# Batch 3610: max input value = 9890
# Batch 3611: max input value = 9675
# Batch 3612: max input value = 9175
# Batch 3613: max input value = 9857
# Batch 3614: max input value = 9755
# Batch 3615: max input value = 9897
# Batch 3616: max input value = 9183
# Batch 3617: max input value = 8445
# Batch 3618: max input value = 9836
# Batch 3619: max input value = 9135
# Batch 3620: max input value = 9948
# Batch 3621: max input value = 9756
# Batch 3622: max input value = 9433
# Batch 3623: max input value = 9999
# Batch 3624: max input value = 9472
# Batch 3625: max input value = 9798
# Batch 3626: max input value = 9882
# Batch 3627: max input value = 8711
# Batch 3628: max input value = 9996
# Batch 3629: max input value = 9429
# Batch 3630: max input value = 9391
# Batch 3631: max input value = 9319
# Batch 3632: max input value = 9956
# Batch 3633: max input value = 9349
# Batch 3634: max input value = 9813
# Batch 3635: max input value = 9874
# Batch 3636: max input value = 9932
# Batch 3637: max input value = 9898
# Batch 3638: max input value = 9998
# Batch 3639: max input value = 9769
# Batch 3640: max input value = 8879
# Batch 3641: max input value = 9499
# Batch 3642: max input value = 9625
# Batch 3643: max input value = 9670
# Batch 3644: max input value = 9815
# Batch 3645: max input value = 9895
# Batch 3646: max input value = 9238
# Batch 3647: max input value = 9641
# Batch 3648: max input value = 9615
# Batch 3649: max input value = 9837
# Batch 3650: max input value = 9265
# Batch 3651: max input value = 9925
# Batch 3652: max input value = 9968
# Batch 3653: max input value = 9994
# Batch 3654: max input value = 9462
# Batch 3655: max input value = 9819
# Batch 3656: max input value = 9776
# Batch 3657: max input value = 9757
# Batch 3658: max input value = 9876
# Batch 3659: max input value = 9376
# Batch 3660: max input value = 8525
# Batch 3661: max input value = 9444
# Batch 3662: max input value = 9461
# Batch 3663: max input value = 9703
# Batch 3664: max input value = 9833
# Batch 3665: max input value = 9609
# Batch 3666: max input value = 9490
# Batch 3667: max input value = 8672
# Batch 3668: max input value = 9695
# Batch 3669: max input value = 9822
# Batch 3670: max input value = 9995
# Batch 3671: max input value = 8718
# Batch 3672: max input value = 9804
# Batch 3673: max input value = 9610
# Batch 3674: max input value = 9397
# Batch 3675: max input value = 9576
# Batch 3676: max input value = 9605
# Batch 3677: max input value = 9975
# Batch 3678: max input value = 9308
# Batch 3679: max input value = 9829
# Batch 3680: max input value = 9658
# Batch 3681: max input value = 9800
# Batch 3682: max input value = 9330
# Batch 3683: max input value = 9914
# Batch 3684: max input value = 9963
# Batch 3685: max input value = 9575
# Batch 3686: max input value = 9756
# Batch 3687: max input value = 9986
# Batch 3688: max input value = 9917
# Batch 3689: max input value = 9950
# Batch 3690: max input value = 9909
# Batch 3691: max input value = 9526
# Batch 3692: max input value = 9807
# Batch 3693: max input value = 9921
# Batch 3694: max input value = 9493
# Batch 3695: max input value = 9085
# Batch 3696: max input value = 9829
# Batch 3697: max input value = 9873
# Batch 3698: max input value = 9879
# Batch 3699: max input value = 9281
# Batch 3700: max input value = 9632
# Epoch 1/5, Batch 3700/52072, Loss: 4.9821
# Batch 3701: max input value = 9834
# Batch 3702: max input value = 9556
# Batch 3703: max input value = 9872
# Batch 3704: max input value = 9721
# Batch 3705: max input value = 8518
# Batch 3706: max input value = 9758
# Batch 3707: max input value = 9512
# Batch 3708: max input value = 9318
# Batch 3709: max input value = 9660
# Batch 3710: max input value = 9247
# Batch 3711: max input value = 8994
# Batch 3712: max input value = 9955
# Batch 3713: max input value = 9778
# Batch 3714: max input value = 9416
# Batch 3715: max input value = 9922
# Batch 3716: max input value = 9826
# Batch 3717: max input value = 9137
# Batch 3718: max input value = 9983
# Batch 3719: max input value = 9941
# Batch 3720: max input value = 9682
# Batch 3721: max input value = 9841
# Batch 3722: max input value = 9810
# Batch 3723: max input value = 9976
# Batch 3724: max input value = 9482
# Batch 3725: max input value = 9919
# Batch 3726: max input value = 9374
# Batch 3727: max input value = 9413
# Batch 3728: max input value = 9954
# Batch 3729: max input value = 9658
# Batch 3730: max input value = 9985
# Batch 3731: max input value = 9730
# Batch 3732: max input value = 9520
# Batch 3733: max input value = 8867
# Batch 3734: max input value = 8992
# Batch 3735: max input value = 9948
# Batch 3736: max input value = 8994
# Batch 3737: max input value = 9638
# Batch 3738: max input value = 9637
# Batch 3739: max input value = 9094
# Batch 3740: max input value = 9864
# Batch 3741: max input value = 8617
# Batch 3742: max input value = 9820
# Batch 3743: max input value = 9448
# Batch 3744: max input value = 9766
# Batch 3745: max input value = 9959
# Batch 3746: max input value = 9158
# Batch 3747: max input value = 9381
# Batch 3748: max input value = 9934
# Batch 3749: max input value = 9687
# Batch 3750: max input value = 9733
# Batch 3751: max input value = 9920
# Batch 3752: max input value = 9945
# Batch 3753: max input value = 9700
# Batch 3754: max input value = 9966
# Batch 3755: max input value = 9099
# Batch 3756: max input value = 9909
# Batch 3757: max input value = 9130
# Batch 3758: max input value = 9092
# Batch 3759: max input value = 9465
# Batch 3760: max input value = 9607
# Batch 3761: max input value = 9469
# Batch 3762: max input value = 9364
# Batch 3763: max input value = 9710
# Batch 3764: max input value = 9574
# Batch 3765: max input value = 9705
# Batch 3766: max input value = 9748
# Batch 3767: max input value = 9785
# Batch 3768: max input value = 9775
# Batch 3769: max input value = 9579
# Batch 3770: max input value = 9642
# Batch 3771: max input value = 9738
# Batch 3772: max input value = 9480
# Batch 3773: max input value = 9670
# Batch 3774: max input value = 8865
# Batch 3775: max input value = 9992
# Batch 3776: max input value = 9059
# Batch 3777: max input value = 9324
# Batch 3778: max input value = 9394
# Batch 3779: max input value = 9484
# Batch 3780: max input value = 9561
# Batch 3781: max input value = 9727
# Batch 3782: max input value = 9683
# Batch 3783: max input value = 9808
# Batch 3784: max input value = 9679
# Batch 3785: max input value = 9288
# Batch 3786: max input value = 9859
# Batch 3787: max input value = 9746
# Batch 3788: max input value = 9520
# Batch 3789: max input value = 9487
# Batch 3790: max input value = 9153
# Batch 3791: max input value = 9055
# Batch 3792: max input value = 8948
# Batch 3793: max input value = 9809
# Batch 3794: max input value = 9743
# Batch 3795: max input value = 9768
# Batch 3796: max input value = 9775
# Batch 3797: max input value = 8778
# Batch 3798: max input value = 9906
# Batch 3799: max input value = 9663
# Batch 3800: max input value = 9896
# Epoch 1/5, Batch 3800/52072, Loss: 5.3632
# Batch 3801: max input value = 9781
# Batch 3802: max input value = 9656
# Batch 3803: max input value = 9619
# Batch 3804: max input value = 9635
# Batch 3805: max input value = 9938
# Batch 3806: max input value = 9938
# Batch 3807: max input value = 8892
# Batch 3808: max input value = 9482
# Batch 3809: max input value = 9992
# Batch 3810: max input value = 9419
# Batch 3811: max input value = 9893
# Batch 3812: max input value = 9591
# Batch 3813: max input value = 9732
# Batch 3814: max input value = 9530
# Batch 3815: max input value = 9274
# Batch 3816: max input value = 9906
# Batch 3817: max input value = 9678
# Batch 3818: max input value = 9957
# Batch 3819: max input value = 9613
# Batch 3820: max input value = 9967
# Batch 3821: max input value = 9918
# Batch 3822: max input value = 9952
# Batch 3823: max input value = 9844
# Batch 3824: max input value = 9907
# Batch 3825: max input value = 9311
# Batch 3826: max input value = 9940
# Batch 3827: max input value = 9343
# Batch 3828: max input value = 9578
# Batch 3829: max input value = 9796
# Batch 3830: max input value = 9824
# Batch 3831: max input value = 9951
# Batch 3832: max input value = 9847
# Batch 3833: max input value = 9389
# Batch 3834: max input value = 9936
# Batch 3835: max input value = 9624
# Batch 3836: max input value = 9163
# Batch 3837: max input value = 9428
# Batch 3838: max input value = 9333
# Batch 3839: max input value = 9364
# Batch 3840: max input value = 9246
# Batch 3841: max input value = 9722
# Batch 3842: max input value = 9924
# Batch 3843: max input value = 9688
# Batch 3844: max input value = 9924
# Batch 3845: max input value = 9416
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 74
#      72 model = Transformer(config)
#      73 print(f"Model vocab size: {model.embedding.num_embeddings}")
# ---> 74 train_transformer(model, int_sequences)
#
# Cell In[34], line 57, in train_transformer(model, int_sequences, context_size, batch_size, num_epochs, learning_rate, device)
#      54 targets = targets.view(-1)
#      56 loss = criterion(outputs, targets)
# ---> 57 loss.backward()
#      58 torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Prevent exploding gradients
#      59 optimizer.step()
#
# File ~/Documents/MATH598B T1000/venv/lib/python3.13/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Documents/MATH598B T1000/venv/lib/python3.13/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Documents/MATH598B T1000/venv/lib/python3.13/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:
